# %%
# import captions_train2014 json and analyze it
import json
import pandas as pd
import os
import sys
import re
import string
from pycocotools.coco import COCO
print(os.getcwd())
file_path = os.path.join(os.getcwd(),'Data','Coco','2014data','annotations','instances_train2014.json')
print(file_path)
coco = COCO(file_path)

coco.dataset['images']
# Out:
# g:\Github\revise-tool
# g:\Github\revise-tool\Data\Coco\2014data\annotations\instances_train2014.json
# loading annotations into memory...
# Done (t=17.17s)
# creating index...
# index created!
# [{'license': 5,
#   'file_name': 'COCO_train2014_000000057870.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000057870.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 16:28:13',
#   'flickr_url': 'http://farm4.staticflickr.com/3153/2970773875_164f0c0b83_z.jpg',
#   'id': 57870},
#  {'license': 5,
#   'file_name': 'COCO_train2014_000000384029.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2014/COCO_train2014_000000384029.jpg',
#   'height': 429,
#   'width': 640,
#   'date_captured': '2013-11-14 16:29:45',
#   'flickr_url': 'http://farm3.staticflickr.com/2422/3577229611_3a3235458a_z.jpg',
#   'id': 384029},
#  {'license': 1,
#   'file_name': 'COCO_train2014_000000222016.jpg',
# ...

# %%
import pickle
gender_data = pickle.load(open('Data/Coco/2014data/bias_splits/train.data', 'rb'))
attribute_data = {int(chunk['img'][15:27]): chunk['annotation'][0] for chunk in gender_data}
attribute_data
# Out:
# {384029: 1,
#  222016: 1,
#  69675: 0,
#  547471: 1,
#  90570: 1,
#  504616: 1,
#  161919: 1,
#  170558: 1,
#  283524: 1,
#  37015: 0,
#  365363: 1,
#  344806: 1,
#  409382: 1,
#  469605: 1,
#  214704: 1,
#  530683: 0,
#  441488: 1,
#  218956: 1,
#  354444: 0,
#  280980: 1,
#  289019: 1,
#  413746: 1,
#  524068: 1,
#  270912: 1,
#  528906: 0,
#  267688: 1,
#  374114: 1,
#  424102: 1,
#  345781: 0,
#  18885: 1,
#  265709: 1,
#  210932: 1,
#  351430: 0,
#  483751: 1,
#  520451: 0,
#  498943: 0,
#  270715: 1,
#  146049: 0,
#  521772: 1,
#  208261: 1,
#  361059: 1,
#  79354: 1,
#  326374: 1,
#  155417: 1,
#  287735: 0,
#  498679: 1,
#  203867: 0,
#  66309: 1,
#  426664: 1,
#  341844: 1,
#  239754: 1,
#  577196: 1,
#  32044: 1,
#  149961: 1,
#  539631: 1,
#  420025: 1,
#  158105: 0,
#  504911: 1,
#  129064: 1,
#  128631: 1,
#  23072: 0,
#  173634: 0,
#  278301: 1,
#  417720: 0,
#  469587: 1,
#  136184: 1,
#  266200: 0,
#  330952: 1,
#  301362: 1,
#  528960: 1,
#  334032: 0,
#  467809: 0,
# ...
